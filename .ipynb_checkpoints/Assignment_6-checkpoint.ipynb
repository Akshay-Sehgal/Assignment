# %%
from matplotlib import pyplot as plt
import seaborn as sb
import pandas as pd

# %%
#Q1. 

ds=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
ds.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
# a.)

sb.kdeplot(ds["MaxTemp"])
sb.kdeplot(ds["MinTemp"])

# %%
sb.swarmplot(x=ds["Location"],y=ds["MinTemp"])

# %%
sb.distplot(ds["Temp9am"])
# Out:
# c:\users\hp-i5-amd\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sb.jointplot(x=ds["Humidity3pm"],y=ds["Temp3pm"],color="red")
# Out:
# c:\users\hp-i5-amd\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sb.jointplot(x=ds["Humidity3pm"],y=ds["Temp3pm"],color="green",kind="kde")

# %%
sb.boxplot(x=ds["Location"],y=ds["Sunshine"])

# %%
sb.barplot(x=ds["Date"],y=ds["MaxTemp"])

# %%
sb.countplot(x=ds["Rainfall"])

# %%
sb.stripplot(x=ds["Date"],y=ds["MaxTemp"])

# %%
ds=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")

# %%
ds=pd.DataFrame([ds["MinTemp"],ds["MaxTemp"],ds["Rainfall"],ds["Evaporation"],ds["Sunshine"]])

# %%
ds=ds.fillna(ds.mean())

# %%
ds=ds.transpose()

# %%
sb.pairplot(ds)
